# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaliGuvi/NASA-NEO-Project/blob/main/NASA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

api_key = "M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s"
url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&api_key={api_key}"

response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data_dic = response.json()   #data as dictionary

# %%
data_dic.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %%
data_dic['near_earth_objects']  #We need only Near earth objects
# Out:
# {'2024-01-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'},
#    'id': '2415949',
#    'neo_reference_id': '2415949',
#    'name': '415949 (2001 XY10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#    'absolute_magnitude_h': 19.37,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#      'estimated_diameter_max': 0.7944013596},
#     'meters': {'estimated_diameter_min': 355.267088298,
#      'estimated_diameter_max': 794.4013596028},
#     'miles': {'estimated_diameter_min': 0.2207526659,
#      'estimated_diameter_max': 0.4936179672},
#     'feet': {'estimated_diameter_min': 1165.5744739718,
#      'estimated_diameter_max': 2606.3037566394}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 13:14',
# ...

# %%
len(data_dic['near_earth_objects'])
# Out:
# 8

# %%
Req_data = data_dic['near_earth_objects']      #stored the required data

# %%
Req_data.items()    # get the values as tuples ('dates','astroid details')
# Out:
# dict_items([('2024-01-02', [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'}, 'id': '2415949', 'neo_reference_id': '2415949', 'name': '415949 (2001 XY10)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949', 'absolute_magnitude_h': 19.37, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883, 'estimated_diameter_max': 0.7944013596}, 'meters': {'estimated_diameter_min': 355.267088298, 'estimated_diameter_max': 794.4013596028}, 'miles': {'estimated_diameter_min': 0.2207526659, 'estimated_diameter_max': 0.4936179672}, 'feet': {'estimated_diameter_min': 1165.5744739718, 'estimated_diameter_max': 2606.3037566394}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-01-02', 'close_approach_date_full': '2024-Jan-02 13:14', 'epoch_date_close_approach': 1704201240000, 'relative_velocity': {'kilometers_per_second': '15.8905264223'
# ...

# %%
type(Req_data.items())
# Out:
# dict_items

# %%
type(Req_data)
# Out:
# dict

# %%
Req_data.keys()
# Out:
# dict_keys(['2024-01-02', '2024-01-01', '2024-01-04', '2024-01-03', '2024-01-06', '2024-01-05', '2024-01-08', '2024-01-07'])

# %%
len(Req_data) #how many days of astroid data available
# Out:
# 8

# %%
Req_data['2024-01-02']  #one day data
# Out:
# [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'},
#   'id': '2415949',
#   'neo_reference_id': '2415949',
#   'name': '415949 (2001 XY10)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#   'absolute_magnitude_h': 19.37,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#     'estimated_diameter_max': 0.7944013596},
#    'meters': {'estimated_diameter_min': 355.267088298,
#     'estimated_diameter_max': 794.4013596028},
#    'miles': {'estimated_diameter_min': 0.2207526659,
#     'estimated_diameter_max': 0.4936179672},
#    'feet': {'estimated_diameter_min': 1165.5744739718,
#     'estimated_diameter_max': 2606.3037566394}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-02',
#     'close_approach_date_full': '2024-Jan-02 13:14',
#     'epoch_date_close_approach': 1704201240000,
# ...

# %%
len(Req_data['2024-01-02'])    #how many astroids came on 2025-01-01
# Out:
# 22

# %%
Req_data['2024-01-02'][0]     #1st astroid details on ['2025-01-01']
# Out:
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'},
#  'id': '2415949',
#  'neo_reference_id': '2415949',
#  'name': '415949 (2001 XY10)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#  'absolute_magnitude_h': 19.37,
#  'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#    'estimated_diameter_max': 0.7944013596},
#   'meters': {'estimated_diameter_min': 355.267088298,
#    'estimated_diameter_max': 794.4013596028},
#   'miles': {'estimated_diameter_min': 0.2207526659,
#    'estimated_diameter_max': 0.4936179672},
#   'feet': {'estimated_diameter_min': 1165.5744739718,
#    'estimated_diameter_max': 2606.3037566394}},
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_data': [{'close_approach_date': '2024-01-02',
#    'close_approach_date_full': '2024-Jan-02 13:14',
#    'epoch_date_close_approach': 1704201240000,
# ...

# %%
Req_data['2024-01-02'][21]
# Out:
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445206?api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'},
#  'id': '54445206',
#  'neo_reference_id': '54445206',
#  'name': '(2024 KJ1)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445206',
#  'absolute_magnitude_h': 26.21,
#  'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152249185,
#    'estimated_diameter_max': 0.0340439527},
#   'meters': {'estimated_diameter_min': 15.2249185036,
#    'estimated_diameter_max': 34.043952726},
#   'miles': {'estimated_diameter_min': 0.0094603228,
#    'estimated_diameter_max': 0.0211539249},
#   'feet': {'estimated_diameter_min': 49.9505216234,
#    'estimated_diameter_max': 111.6927618614}},
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_data': [{'close_approach_date': '2024-01-02',
#    'close_approach_date_full': '2024-Jan-02 11:41',
#    'epoch_date_close_approach': 1704195660000,
# ...

# %%
Req_data['2024-01-02'][22]        # bcs we have only 22 astroids, we can give 21 as max index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 Req_data['2024-01-02'][22]
#
# IndexError: list index out of range

# %%
day1_data = Req_data['2024-01-02']         #1st day near_earth_objects data

# %%
day1_data[0]['id']      #0th = index, means 1st astroid on'2025-01-01' out of 14 astroids in the list, and id of 1st astroid
# Out:
# '2415949'

# %%
Req_data.items()    # get the values as tuples ('dates','astroid details') So, we can use in for loop
# Out:
# dict_items([('2024-01-02', [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'}, 'id': '2415949', 'neo_reference_id': '2415949', 'name': '415949 (2001 XY10)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949', 'absolute_magnitude_h': 19.37, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883, 'estimated_diameter_max': 0.7944013596}, 'meters': {'estimated_diameter_min': 355.267088298, 'estimated_diameter_max': 794.4013596028}, 'miles': {'estimated_diameter_min': 0.2207526659, 'estimated_diameter_max': 0.4936179672}, 'feet': {'estimated_diameter_min': 1165.5744739718, 'estimated_diameter_max': 2606.3037566394}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-01-02', 'close_approach_date_full': '2024-Jan-02 13:14', 'epoch_date_close_approach': 1704201240000, 'relative_velocity': {'kilometers_per_second': '15.8905264223'
# ...

# %%
for date,astro_detail in Req_data.items():
    print(date,astro_detail)
# Out:
# 2024-01-02 [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'}, 'id': '2415949', 'neo_reference_id': '2415949', 'name': '415949 (2001 XY10)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949', 'absolute_magnitude_h': 19.37, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883, 'estimated_diameter_max': 0.7944013596}, 'meters': {'estimated_diameter_min': 355.267088298, 'estimated_diameter_max': 794.4013596028}, 'miles': {'estimated_diameter_min': 0.2207526659, 'estimated_diameter_max': 0.4936179672}, 'feet': {'estimated_diameter_min': 1165.5744739718, 'estimated_diameter_max': 2606.3037566394}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-01-02', 'close_approach_date_full': '2024-Jan-02 13:14', 'epoch_date_close_approach': 1704201240000, 'relative_velocity': {'kilometers_per_second': '15.8905264223', 'kilometers_pe
# ...

# %%
astroids_data = []       #required data for 8 days

for date,astro_detail in Req_data.items():
    for i in astro_detail:
        astroids_data.append(dict(ID = i['id'],
        Neo_reference_id = ['neo_reference_id'],
        Name = ['name'],
        Absolute_magnitude_h = ['absolute_magnitude_h'],
        Estimated_diameter_min_km = ['estimated_diameter_min_km'],
        Estimated_diameter_max_km = ['estimated_diameter_max_km'],
        Is_potentially_hazardous_asteroid = ['is_potentially_hazardous_asteroid'],
        Close_approach_data = ['close_approach_data'],
        Relative_velocity_kmph = ['relative_velocity'],
        Astronomical = ['astronomical'],
        Miss_distance_km = ['miss_distance'],
        Miss_distance_lunar = ['miss_distance'],
        Orbiting_body = ['orbiting_body']))

# %%
astroids_data
# Out:
# [{'ID': '2415949',
#   'Neo_reference_id': ['neo_reference_id'],
#   'Name': ['name'],
#   'Absolute_magnitude_h': ['absolute_magnitude_h'],
#   'Estimated_diameter_min_km': ['estimated_diameter_min_km'],
#   'Estimated_diameter_max_km': ['estimated_diameter_max_km'],
#   'Is_potentially_hazardous_asteroid': ['is_potentially_hazardous_asteroid'],
#   'Close_approach_data': ['close_approach_data'],
#   'Relative_velocity_kmph': ['relative_velocity'],
#   'Astronomical': ['astronomical'],
#   'Miss_distance_km': ['miss_distance'],
#   'Miss_distance_lunar': ['miss_distance'],
#   'Orbiting_body': ['orbiting_body']},
#  {'ID': '3160747',
#   'Neo_reference_id': ['neo_reference_id'],
#   'Name': ['name'],
#   'Absolute_magnitude_h': ['absolute_magnitude_h'],
#   'Estimated_diameter_min_km': ['estimated_diameter_min_km'],
#   'Estimated_diameter_max_km': ['estimated_diameter_max_km'],
#   'Is_potentially_hazardous_asteroid': ['is_potentially_hazardous_asteroid'],
# ...

# %%
data_dic.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %%
data_dic['element_count']
# Out:
# 130

# %%
len(astroids_data) # I have got all the elements from 1 week data
# Out:
# 130

# %%
astroids_data = []

for date,astro_detail in Req_data.items():
    for i in day1_data:
        astroids_data.append(dict(ID = i['id'],
        Neo_reference_id = i['neo_reference_id'],
        Name = i['name'],
        Absolute_magnitude_h = i['absolute_magnitude_h'],
        Estimated_diameter_min_km = i['estimated_diameter'],  # how to get the specific info from { braket details
        Estimated_diameter_max_km = i['estimated_diameter'], # how to get the specific info from { braket details
        Is_potentially_hazardous_asteroid = i['is_potentially_hazardous_asteroid'],
        Close_approach_data = i['close_approach_data']))

# %%
astroids_data
# Out:
# [{'ID': '2415949',
#   'Neo_reference_id': '2415949',
#   'Name': '415949 (2001 XY10)',
#   'Absolute_magnitude_h': 19.37,
#   'Estimated_diameter_min_km': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#     'estimated_diameter_max': 0.7944013596},
#    'meters': {'estimated_diameter_min': 355.267088298,
#     'estimated_diameter_max': 794.4013596028},
#    'miles': {'estimated_diameter_min': 0.2207526659,
#     'estimated_diameter_max': 0.4936179672},
#    'feet': {'estimated_diameter_min': 1165.5744739718,
#     'estimated_diameter_max': 2606.3037566394}},
#   'Estimated_diameter_max_km': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#     'estimated_diameter_max': 0.7944013596},
#    'meters': {'estimated_diameter_min': 355.267088298,
#     'estimated_diameter_max': 794.4013596028},
#    'miles': {'estimated_diameter_min': 0.2207526659,
#     'estimated_diameter_max': 0.4936179672},
#    'feet': {'estimated_diameter_min': 1165.5744739718,
# ...

# %%
astroids_data = []       #required data for 10000 days
target = 10000

url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&api_key={api_key}"

while len(astroids_data) < target:
    response = requests.get(url)
    data_dic = response.json()
    Req_data = data_dic['near_earth_objects']
    for date,astro_detail in Req_data.items():
        for i in day1_data:
            astroids_data.append(dict(ID = i['id'],
            Neo_reference_id = i['neo_reference_id'],
            Name = i['name'],
            Absolute_magnitude_h = i['absolute_magnitude_h'],
            Estimated_diameter_min_km = i['estimated_diameter'],
            Estimated_diameter_max_km = i['estimated_diameter'],
            Is_potentially_hazardous_asteroid = i['is_potentially_hazardous_asteroid'],
            Close_approach_date = i['close_approach_data']))
            if len(astroids_data) >= target:
                break
        if len(astroids_data) >= target:
            break


    url = data_dic['links']['next']    #the next url will get added for next 7 days data until we get 10000 data

# %%
data_dic['links']
# Out:
# {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-08&end_date=2024-01-15&detailed=false&api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s',
#  'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2023-12-25&end_date=2024-01-01&detailed=false&api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s',
#  'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&detailed=false&api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'}

# %%
astroids_data[0]
# Out:
# {'ID': '2415949',
#  'Neo_reference_id': '2415949',
#  'Name': '415949 (2001 XY10)',
#  'Absolute_magnitude_h': 19.37,
#  'Estimated_diameter_min_km': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#    'estimated_diameter_max': 0.7944013596},
#   'meters': {'estimated_diameter_min': 355.267088298,
#    'estimated_diameter_max': 794.4013596028},
#   'miles': {'estimated_diameter_min': 0.2207526659,
#    'estimated_diameter_max': 0.4936179672},
#   'feet': {'estimated_diameter_min': 1165.5744739718,
#    'estimated_diameter_max': 2606.3037566394}},
#  'Estimated_diameter_max_km': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#    'estimated_diameter_max': 0.7944013596},
#   'meters': {'estimated_diameter_min': 355.267088298,
#    'estimated_diameter_max': 794.4013596028},
#   'miles': {'estimated_diameter_min': 0.2207526659,
#    'estimated_diameter_max': 0.4936179672},
#   'feet': {'estimated_diameter_min': 1165.5744739718,
# ...

# %%
len(astroids_data)
# Out:
# 10000

# %%
'Close_approach_data': [{'close_approach_date': '2025-01-01','close_approach_date_full': '2025-Jan-01 10:18','epoch_date_close_approach': 1735726680000,
     'relative_velocity': {'kilometers_per_second': '15.9737833452','kilometers_per_hour': '57505.6200425926','miles_per_hour': '35731.7559647987'},
     'miss_distance': {'astronomical': '0.0429341231','lunar': '16.7013738859','kilometers': '6422853.366077797','miles': '3990976.0176637186'},
    'orbiting_body':'Earth'}]  # it is one eleement list, all the values are in one dict{}. when we call the value in list, we should use the index of the value.
                                #so [0]. ex: [Close_approach_data][0][close_approach_date]
                                #to call the value from dict need to mention the key ex: [Close_approach_data][0]['relative_velocity']['kilometers_per_hour']
# Out:
#   Cell In[311], line 1
#     'Close_approach_data': [{'close_approach_date': '2025-01-01','close_approach_date_full': '2025-Jan-01 10:18','epoch_date_close_approach': 1735726680000,
#     ^
# SyntaxError: illegal target for annotation

# %%
# use datastring to convert the string into date format

#Syntax:
#from datetime import datetime

#date_string = "2025-04-23 10:30:00"
#date_format = "%Y-%m-%d %H:%M:%S"

#date_object = datetime.strptime(date_string, date_format)

# %%
from datetime import datetime
astroids_data = []       #required data for 10000 days
target = 10000

url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&api_key={api_key}"

while len(astroids_data) < target:
    response = requests.get(url)
    data_dic = response.json()
    Req_data = data_dic['near_earth_objects']
    for date,astro_detail in Req_data.items():
        for i in astro_detail:

            astroids_data.append(dict(ID = int(i['id']),
            Neo_reference_id = int(i['neo_reference_id']),
            Name = i['name'],
            Absolute_magnitude_h = i['absolute_magnitude_h'],
            Estimated_diameter_min_km = i['estimated_diameter']['kilometers']['estimated_diameter_min'],
            Estimated_diameter_max_km = i['estimated_diameter']['kilometers']['estimated_diameter_max'],
            Is_potentially_hazardous_asteroid = i['is_potentially_hazardous_asteroid'],
            Close_approach_date = datetime.strptime(i['close_approach_data'][0]['close_approach_date'], "%Y-%m-%d").date(),
            Relative_velocity_kmph = float(i['close_approach_data'][0]['relative_velocity']['kilometers_per_hour']),
            Astronomical = float(i['close_approach_data'][0]['miss_distance']['astronomical']),
            miss_distance_km = float(i['close_approach_data'][0]['miss_distance']['kilometers']),
            miss_distance_lunar = float(i['close_approach_data'][0]['miss_distance']['lunar']),
            orbiting_body = i['close_approach_data'][0]['orbiting_body']))
            if len(astroids_data) >= target:
                break
        if len(astroids_data) >= target:
            break


    url = data_dic['links']['next']

# %%
data_dic['links']['next']
# Out:
# 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2025-04-28&end_date=2025-05-05&detailed=false&api_key=M0yCoVkppa6G7ZqpF5KYce3eloncodnAJcMfvP8s'

# %%
astroids_data
# Out:
# [{'ID': 2415949,
#   'Neo_reference_id': 2415949,
#   'Name': '415949 (2001 XY10)',
#   'Absolute_magnitude_h': 19.37,
#   'Estimated_diameter_min_km': 0.3552670883,
#   'Estimated_diameter_max_km': 0.7944013596,
#   'Is_potentially_hazardous_asteroid': False,
#   'Close_approach_date': datetime.date(2024, 1, 2),
#   'Relative_velocity_kmph': 57205.8951204341,
#   'Astronomical': 0.3372535274,
#   'miss_distance_km': 50452409.349026635,
#   'miss_distance_lunar': 131.1916221586,
#   'orbiting_body': 'Earth'},
#  {'ID': 3160747,
#   'Neo_reference_id': 3160747,
#   'Name': '(2003 SR84)',
#   'Absolute_magnitude_h': 26.0,
#   'Estimated_diameter_min_km': 0.0167708462,
#   'Estimated_diameter_max_km': 0.0375007522,
#   'Is_potentially_hazardous_asteroid': False,
#   'Close_approach_date': datetime.date(2024, 1, 2),
#   'Relative_velocity_kmph': 38589.054833182,
#   'Astronomical': 0.1323425924,
#   'miss_distance_km': 19798169.933318187,
#   'miss_distance_lunar': 51.4812684436,
# ...

# %%
len(astroids_data)
# Out:
# 10000

# %%
 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2492039814,
     'estimated_diameter_max': 0.5572370428},
    'meters': {'estimated_diameter_min': 249.2039814409,
     'estimated_diameter_max': 557.2370427654},
    'miles': {'estimated_diameter_min': 0.1548481272,
     'estimated_diameter_max': 0.3462509385},
    'feet': {'estimated_diameter_min': 817.5983904706,
     'estimated_diameter_max': 1828.2055793866}}     # Estimated_diameter is a dict. and Kilometers is one more dict inside Estimatted_diameter.
                                                      #to call the values from dict, need to call using the key.
                                                #ex: ['estimated_diameter']['kilometers']['estimated_diameter_min']
# Out:
#   Cell In[321], line 1
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2492039814,
#     ^
# SyntaxError: illegal target for annotation

# %%
# !pip install pymysql   #connecting to sql

# %%
import pymysql    #Create a cursor object

connection = pymysql.connect(
    host = "localhost",
    user = 'root',
    password = "Wonder*555",  #your actual password of your sql profile
    database = "market"  #it should match with the database created in mysql
)

# %%
cursor = connection.cursor()

# %%
cursor.execute("""create table asteroids_data(ID INT, Name VARCHAR(100), Absolute_magnitude_h FLOAT, Estimated_diameter_min_km FLOAT, Estimated_diameter_max_km FLOAT, Is_potentially_hazardous_asteroid BOOLEAN)""")
# Out:
# 0

# %%
insert = """insert into asteroids_data(ID, Name, Absolute_magnitude_h, Estimated_diameter_min_km, Estimated_diameter_max_km, Is_potentially_hazardous_asteroid)values(%s,%s,%s,%s,%s,%s)"""

for i in astroids_data:
    values = (i['ID'], i['Name'], i['Absolute_magnitude_h'], i['Estimated_diameter_min_km'], i['Estimated_diameter_max_km'], i['Is_potentially_hazardous_asteroid'])
    cursor.execute(insert, values)

connection.commit()                    #to insert the info into table in sql # table 1 asteroids

# %%
cursor.execute("""create table close_approaches(Neo_reference_id INT, Close_approach_date DATE, Relative_velocity_kmph FLOAT, Astronomical FLOAT, Miss_distance_km FLOAT, Miss_distance_lunar FLOAT, Orbiting_body VARCHAR(100))""")
# Out:
# 0

# %%
insert = """insert into close_approaches(Neo_reference_id, Close_approach_date, Relative_velocity_kmph, Astronomical, Miss_distance_km, Miss_distance_lunar, Orbiting_body)values(%s,%s,%s,%s,%s,%s,%s)"""

for i in astroids_data:
    values = (i['Neo_reference_id'], i['Close_approach_date'], i['Relative_velocity_kmph'], i['Astronomical'], i['miss_distance_km'], i['miss_distance_lunar'], i['orbiting_body'])
    cursor.execute(insert, values)

connection.commit()                      #to insert the info into table in sql # table 2 close_approach

# %%
astroids_data[9999]
# Out:
# {'ID': 54527448,
#  'Neo_reference_id': 54527448,
#  'Name': '(2025 HV2)',
#  'Absolute_magnitude_h': 23.881,
#  'Estimated_diameter_min_km': 0.0444994842,
#  'Estimated_diameter_max_km': 0.0995038715,
#  'Is_potentially_hazardous_asteroid': False,
#  'Close_approach_date': datetime.date(2025, 4, 21),
#  'Relative_velocity_kmph': 57240.2258120952,
#  'Astronomical': 0.0615135314,
#  'miss_distance_km': 9202293.273618119,
#  'miss_distance_lunar': 23.9287637146,
#  'orbiting_body': 'Earth'}

# %%
connection.close()
